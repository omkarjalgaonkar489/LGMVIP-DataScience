# %% [markdown]
# __LGM-VIP Data Science__

# %% [markdown]
# __Task 1: Iris Flowers Classification__

# %% [markdown]
# __Importing the required libraries__

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

# %% [markdown]
# __Loading the Dataset__

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.rename(columns={"Unnamed: 0":"Id", "Sepal.Length":"SepalLengthCm", "Sepal.Width":"SepalWidthCm", "Petal.Length":"PetalLengthCm", "Petal.Width":"PetalWidthCm" },inplace=True)

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.057333       3.758000      1.199333
# std     43.445368       0.828066      0.435866       1.765298      0.762238
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# __To find the no. of flowers present in each species__

# %%
iris["Species"].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: Species, dtype: int64

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0   1            5.1           3.5            1.4           0.2  setosa
# 1   2            4.9           3.0            1.4           0.2  setosa
# 2   3            4.7           3.2            1.3           0.2  setosa
# 3   4            4.6           3.1            1.5           0.2  setosa
# 4   5            5.0           3.6            1.4           0.2  setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 145  146            6.7           3.0            5.2           2.3  virginica
# 146  147            6.3           2.5            5.0           1.9  virginica
# 147  148            6.5           3.0            5.2           2.0  virginica
# 148  149            6.2           3.4            5.4           2.3  virginica
# 149  150            5.9           3.0            5.1           1.8  virginica

# %%
iris.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.402301       0.882637
# SepalLengthCm  0.716676       1.000000     -0.117570       0.871754
# SepalWidthCm  -0.402301      -0.117570      1.000000      -0.428440
# PetalLengthCm  0.882637       0.871754     -0.428440       1.000000
# PetalWidthCm   0.900027       0.817941     -0.366126       0.962865
#
#                PetalWidthCm
# Id                 0.900027
# SepalLengthCm      0.817941
# SepalWidthCm      -0.366126
# PetalLengthCm      0.962865
# PetalWidthCm       1.000000

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# __Scatter Plot:__

# %%
iris.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm' )
plt.show()

# %%
plt.style.use('seaborn')
sns.FacetGrid(iris,hue='Species',height=5).\
            map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
            .add_legend()

# %% [markdown]
# __Here, we can observe that we can differentiate Setosa flowers from other type of flowers.__

# %% [markdown]
# __Whereas, Versicolor and Vergina are overlapping with each other.__

# %% [markdown]
# __Pair Plot:__

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", height=4)

# %% [markdown]
# __Box Plot:__

# %%
sns.boxplot(x="Species", y="PetalWidthCm", data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# __Violin Plot:__

# %%
sns.violinplot(x='Species', y='PetalLengthCm', data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# __Heatmap:__

# %%
sns.heatmap(iris.corr(),cmap='Blues',annot=True,linewidths=1)
plt.show()

# %%
X=iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=iris['Species']

# %% [markdown]
# __Training and Testing Data__

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (120,)
# (30, 4)
# (30,)

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# __Support Vector Machine__

# %%
from sklearn import svm
model=svm.SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# __Decision Tree Classifier__

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy',max_depth=5,random_state=16)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=16)

# %%
y_pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# __Random Forest Classifier__

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# __K Nearest Neighbors Classifier__

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# __Naive Bayes Classifier__

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy: 1.0

# %% [markdown]
# __Conclusion: We can observe here that Naive Bayes gives 100% accuracy.__
